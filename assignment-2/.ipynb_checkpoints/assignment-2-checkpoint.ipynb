# %% [markdown]
# # Problem 1: scraping houses prices
#
# ## Strategy
# Loop over all the pages.
# For each page, loop over all the list items:
# ```html
# <li class="sold-results__normal-hit">
#   ...
# </li>
# ```
# For each list item, extract the following information:
# ### Sold date:
# ```html
# <span class="hcl-label hcl-label--state hcl-label--sold-at">
#     Såld 9 oktober 2023
# </span>
# ```
# remove the "Såld " prefix
#
# ### Address:
# ```html
# <h2 class="sold-property-listing__heading qa-selling-price-title hcl-card__title">
#   Skårby station 350
# </h2>
# ```
# ### Location of the estate:
# ```html
#    <div class="sold-property-listing__location">
#      <div>
#        <span class="property-icon property-icon--result">...</span>
#        Kareby,
#        Kungälvs kommun
#      </div>
#    </div>
# ```
# access the div child and remove the span element
#
# ### Area of the house & number of rooms:
# ```html
# <div class="sold-property-listing__subheading sold-property-listing__area">
#     143
#       <span class="listing-card__attribute--normal-weight">
#         + 25&nbsp;m²
#       </span>
#     &nbsp;
#     7&nbsp;rum
# </div>
# ```
# OR
# ```html
# <div class="sold-property-listing__subheading sold-property-listing__area">
#   123&nbsp;m²
#   &nbsp;
#   6&nbsp;rum
# </div>
# ```
# remove the span element if present, remove the m² and rum suffixes
# save the biarea if a "+" is present
#
# ### Area of the plot:
# ```html
# <div class="sold-property-listing__land-area">
#   2&nbsp;963&nbsp;m² tomt
# </div>
# ```
# remove the m² tomt suffix
#
# ### Closing price:
# ```html
# <span class="hcl-text hcl-text--medium">
#   Slutpris 4&nbsp;395&nbsp;000&nbsp;kr
# </span>
# ```
# remove the "Slutpris " prefix and the kr suffix
#
# ---

# %%
import glob
from bs4 import BeautifulSoup

# %% [markdown]
# Loop over all the pages.

# %%
file_pattern = "kungalv_slutpriser/kungalv_slutpris_page_*.html"

l = []

for file_name in glob.glob(file_pattern):
	with open(file_name, "r") as f:
		content = f.read()
		soup = BeautifulSoup(content, "html.parser")
		print("file_name:", file_name)
		for li in soup.find_all("li", class_="sold-results__normal-hit"):
			# Sold date
			sold_date_element = li.find(
				"span", class_="hcl-label hcl-label--state hcl-label--sold-at"
			)
			sold_date = None
			if sold_date_element is not None:
				sold_date = sold_date_element.text.strip()
				sold_date = sold_date.replace("Såld ", "")

			# Address
			address_element = li.find(
				"h2", class_="sold-property-listing__heading qa-selling-price-title hcl-card__title"
			)
			address = None
			if address_element is not None:
				address = address_element.text.strip()

			# Location
			location_element = li.find("div", class_="sold-property-listing__location").div
			location = None
			if location_element is not None:
				location_element.find("span").decompose()
				location = location_element.text.strip()
			
			area_element = li.find("div", class_="sold-property-listing__subheading sold-property-listing__area")
			boarea = None
			biarea = None
			if area_element is not None:
				if area_element.find("span") is not None:
					biarea = area_element.find("span").text.strip()
					biarea = biarea.replace(" m²", "")
					biarea = biarea.replace("+ ", "")
					area_element.find("span").decompose()
				boarea = area_element.text.strip().split("\xa0")[0]
				boarea = boarea.replace(" m²", "")
				# rooms = area_element.text.strip().split("\xa0")[1]
				rooms = rooms.replace(" rum", "")

			# Plot
			plot_element = li.find("div", class_="sold-property-listing__land-area")
			plot = None
			if plot_element is not None:
				plot = plot_element.text.strip()
				plot = plot.replace(" m² tomt", "")
			
			price_element = li.find("span", class_="hcl-text hcl-text--medium")
			price = None
			if price_element is not None:
				price = price_element.text.strip()
				price = price.replace("Slutpris ", "")
				price = price.replace(" kr", "")
			
			print("sold_date:", sold_date)
			print("address:", address)
			print("location:", location)
			print("boarea:", boarea)
			print("biarea:", biarea)
			print("rooms:", rooms)
			print("plot:", plot)
			print("price:", price)
			print("-------------------------")
# Out:
# file_name: kungalv_slutpriser/kungalv_slutpris_page_27.html
# sold_date: 23 november 2017
# address: Sjöhåla 580
# location: Kovikshamn,
#           Kungälvs kommun
# boarea: 94
#
#
# biarea: 87 m²
# rooms:
#                 6
# plot: 1 068 m² tomt
# price: 3 100 000 kr
# -------------------------
# sold_date: 18 november 2017
# address: Galeasgatan 15
# location: Kungälv,
#           Kungälvs kommun
# boarea: 103
#
#
# biarea: 64 m²
# rooms:
#                 6
# plot: 610 m² tomt
# price: 3 850 000 kr
# -------------------------
# sold_date: 17 november 2017
# address: Västerhöjdsvägen 36
# location: Kärna,
#           Kungälvs kommun
# boarea: 107
# biarea: None
# rooms:
#                 6
# plot: 258 m² tomt
# price: 4 000 000 kr
# -------------------------
# sold_date: 16 november 2017
# address: Gråstensvägen 19
# location: Kode Halltorp,
#           Kungälvs kommun
# boarea: 94
# biarea: None
# rooms:
#                 6
# plot: 1 197 m² tomt
# price: 3 200 000 kr
# -------------------------
# sold_date: 16 november 2017
# address: Hägnan 135
# location: KAREBY,
#           Kungälvs kommun
# boarea: 235
# biarea: None
# rooms:
#                 6
# plot: 104 335 m² tomt
# price: 8 800 000 kr
# -------------------------
# sold_date: 15 november 2017
# address: Rishammarvägen 17
# location: Kareby,
#           Kungälvs kommun
# boarea: 120
#
#
# biarea: 80 m²
# rooms:
#                 6
# plot: 1 142 m² tomt
# price: 4 375 000 kr
# -------------------------
# sold_date: 10 november 2017
# address: Nygatan 14
# location: Marstrand - Koön,
#           Kungälvs kommun
# boarea: 167
#
#
# biarea: 80 m²
# rooms:
#                 6
# plot: 677 m² tomt
# price: 10 800 000 kr
# -------------------------
# sold_date: 5 november 2017
# address: Granndalen 7
# location: Lycke,
#           Kungälvs kommun
# boarea: 50
# biarea: None
# rooms:
#                 6
# plot: 1 465 m² tomt
# price: 1 875 000 kr
# -------------------------
# sold_date: 1 november 2017
# address: Skårby 670
# location: Kareby,
#           Kungälvs kommun
# boarea: 143
# biarea: None
# rooms:
#                 6
# plot: 4 813 m² tomt
# price: 3 000 000 kr
# -------------------------
# sold_date: 1 november 2017
# address: Kodevägen 3
# location: KODE,
#           Kungälvs kommun
# boarea: 150
#
#
# biarea: 50 m²
# rooms:
#                 6
# plot: 2 025 m² tomt
# price: 4 300 000 kr
# -------------------------
# sold_date: 31 oktober 2017
# address: Matskärsvägen 12A
# location: Lycke,
#           Kungälvs kommun
# boarea: 145
# biarea: None
# rooms:
#                 6
# plot: 249 m² tomt
# price: 4 500 000 kr
# -------------------------
# sold_date: 31 oktober 2017
# address: Årsnäs 290
# location: Årsnäs,
#           Kungälvs kommun
# boarea: 167
# biarea: None
# rooms:
#                 6
# plot: 2 558 m² tomt
# price: 4 950 000 kr
# -------------------------
# sold_date: 27 oktober 2017
# address: Staby 350
# location: Kärna,
#           Kungälvs kommun
# boarea: 110
#
#
# biarea: 80 m²
# rooms:
#                 6
# plot: 911 m² tomt
# price: 2 425 000 kr
# -------------------------
# sold_date: 27 oktober 2017
# address: Vråstigen 6
# location: Överön / Vråkärr,
#           Kungälvs kommun
# boarea: 100
# biarea: None
# rooms:
#                 6
# plot: 1 453 m² tomt
# price: 2 475 000 kr
# -------------------------
# sold_date: 26 oktober 2017
# address: Bergkristallvägen 23
# location: Kode,
#           Kungälvs kommun
# boarea: 130
# biarea: None
# rooms:
#                 6
# plot: 504 m² tomt
# price: 4 780 000 kr
# -------------------------
# sold_date: 23 oktober 2017
# address: Östra Gatan 9
# location: Centrum,
#           Kungälvs kommun
# boarea: 325
#
#
# biarea: 82 m²
# rooms:
#                 6
# plot: 359 m² tomt
# price: 7 900 000 kr
# -------------------------
# sold_date: 21 oktober 2017
# address: Kållen 160
# location: Norrmannebo,
#           Kungälvs kommun
# boarea: 88
# biarea: None
# rooms:
#                 6
# plot: 1 819 m² tomt
# price: 1 650 000 kr
# -------------------------
# sold_date: 20 oktober 2017
# address: Fredkullagatan 8
# location: Komarken,
#           Kungälvs kommun
# boarea: 175
#
#
# biarea: 100 m²
# rooms:
#                 6
# plot: 741 m² tomt
# price: 7 160 000 kr
# -------------------------
# sold_date: 20 oktober 2017
# address: Jakobsvägen 7
# location: Kode,
#           Kungälvs kommun
# boarea: 188
# biarea: None
# rooms:
#                 6
# plot: 1 324 m² tomt
# price: 5 475 000 kr
# -------------------------
# sold_date: 16 oktober 2017
# address: Mjölnarvägen 13
# location: Diseröd,
#           Kungälvs kommun
# boarea: 158
#
#
# biarea: 59 m²
# rooms:
#                 6
# plot: 899 m² tomt
# price: 3 965 000 kr
# -------------------------
# sold_date: 13 oktober 2017
# address: Klövergången 15
# location: Centrum,
#           Kungälvs kommun
# boarea: 125
# biarea: None
# rooms:
#                 6
# plot: 401 m² tomt
# price: 4 150 000 kr
# -------------------------
# sold_date: 13 oktober 2017
# address: Kulperödsvägen 5A
# location: Gullbringa,
#           Kungälvs kommun
# boarea: 100
#
#
# biarea: 20 m²
# rooms:
#                 6
# plot: 450 m² tomt
# price: 2 495 000 kr
# -------------------------
# sold_date: 13 oktober 2017
# address: Stora Ryr 130
# location: Lycke,
#           Kungälvs kommun
# boarea: 80
#
#
# biarea: 20 m²
# rooms:
#                 6
# plot: 2 270 m² tomt
# price: 1 600 000 kr
# -------------------------
# sold_date: 12 oktober 2017
# address: Röd 140
# location: Kareby,
#           Kungälvs kommun
# boarea: 122
#
#
# biarea: 11 m²
# rooms:
#                 6
# plot: 2 052 m² tomt
# price: 3 400 000 kr
# -------------------------
# sold_date: 12 oktober 2017
# address: Smaragdvägen 48
# location: Kode,
#           Kungälvs kommun
# boarea: 133
# biarea: None
# rooms:
#                 6
# plot: 368 m² tomt
# price: 3 700 000 kr
# -------------------------
# sold_date: 10 oktober 2017
# address: Ulvesund 405
# location: Ytterby - Ulvesund,
#           Kungälvs kommun
# boarea: 72
# biarea: None
# rooms:
#                 6
# plot: 681 m² tomt
# price: 2 670 000 kr
# -------------------------
# sold_date: 9 oktober 2017
# address: Åsebyberg 853
# location: Åseby,
#           Kungälvs kommun
# boarea: 137
# biarea: None
# rooms:
#                 6
# plot: 1 462 m² tomt
# price: 4 150 000 kr
# -------------------------
# sold_date: 6 oktober 2017
# address: Toftebergsvägen 2
# location: Tjuvkil,
#           Kungälvs kommun
# boarea: 84
# biarea: None
# rooms:
#                 6
# plot: 1 085 m² tomt
# price: 3 700 000 kr
# -------------------------
# sold_date: 5 oktober 2017
# address: Kärnavägen 4
# location: Kärna,
#           Kungälvs kommun
# boarea: 110
#
#
# biarea: 90 m²
# rooms:
#                 6
# plot: 860 m² tomt
# price: 4 100 000 kr
# -------------------------
# sold_date: 5 oktober 2017
# address: Enekullsvägen 28
# location: Enekullen,
#           Kungälvs kommun
# boarea: 125
#
#
# biarea: 18 m²
# rooms:
#                 6
# plot: 789 m² tomt
# price: 4 100 000 kr
# -------------------------
# sold_date: 3 oktober 2017
# address: Skårshöjd 8
# location: Kärna,
#           Kungälvs kommun
# boarea: 120
#
#
# biarea: 40 m²
# rooms:
#                 6
# plot: 900 m² tomt
# price: 2 700 000 kr
# -------------------------
# sold_date: 2 oktober 2017
# address: Lundby 280
# location: Kareby 1,
#           Kungälvs kommun
# boarea: 85
# biarea: None
# rooms:
#                 6
# plot: 2 056 m² tomt
# price: 3 250 000 kr
# -------------------------
# sold_date: 29 september 2017
# address: Rosenstensvägen 3
# location: Kode,
#           Kungälvs kommun
# boarea: 143
# biarea: None
# rooms:
#                 6
# plot: 458 m² tomt
# price: 4 000 000 kr
# -------------------------
# sold_date: 25 september 2017
# address: Bräcke 330
# location: Kärna,
#           Kungälvs kommun
# boarea: 86
# biarea: None
# rooms:
#                 6
# plot: 1 188 m² tomt
# price: 2 800 000 kr
# -------------------------
# sold_date: 22 september 2017
# address: Ulvesund 419
# location: Kungälv - Ulvesund,
#           Kungälvs kommun
# boarea: 65
# biarea: None
# rooms:
#                 6
# plot: 688 m² tomt
# price: 2 710 000 kr
# -------------------------
# sold_date: 21 september 2017
# address: Bergåsvägen 23
# location: Ytterby,
#           Kungälvs kommun
# boarea: 131
#
#
# biarea: 37 m²
# rooms:
#                 6
# plot: 1 267 m² tomt
# price: 4 575 000 kr
# -------------------------
# sold_date: 20 september 2017
# address: Vävra 710
# location: Hålta,
#           Kungälvs kommun
# boarea: 100
#
#
# biarea: 100 m²
# rooms:
#                 6
# plot: 4 794 m² tomt
# price: 3 650 000 kr
# -------------------------
# sold_date: 20 september 2017
# address: Trätäljagatan 2
# location: Iskällan,
#           Kungälvs kommun
# boarea: 147
#
#
# biarea: 147 m²
# rooms:
#                 6
# plot: 937 m² tomt
# price: 5 875 000 kr
# -------------------------
# sold_date: 14 september 2017
# address: Håkons gata 6
# location: Iskällan,
#           Kungälvs kommun
# boarea: 117
# biarea: None
# rooms:
#                 6
# plot: 960 m² tomt
# price: 4 950 000 kr
# -------------------------
# sold_date: 10 september 2017
# address: Torp 340
# location: Kareby,
#           Kungälvs kommun
# boarea: 127
#
#
# biarea: 100 m²
# rooms:
#                 6
# plot: 21 023 m² tomt
# price: 4 325 000 kr
# -------------------------
# sold_date: 8 september 2017
# address: Västra Åkerhögsvägen 17
# location: Kärna,
#           Kungälvs kommun
# boarea: 155
#
#
# biarea: 20 m²
# rooms:
#                 6
# plot: 1 824 m² tomt
# price: 4 575 000 kr
# -------------------------
# sold_date: 7 september 2017
# address: Rävo 170
# location: Hålta,
#           Kungälvs kommun
# boarea: 165
#
#
# biarea: 60 m²
# rooms:
#                 6
# plot: 4 627 m² tomt
# price: 7 150 000 kr
# -------------------------
# sold_date: 7 september 2017
# address: Törnrosgatan 5
# location: Ytterby Tornhaga,
#           Kungälvs kommun
# boarea: 195
# biarea: None
# rooms:
#                 6
# plot: 1 075 m² tomt
# price: 4 555 000 kr
# -------------------------
# sold_date: 5 september 2017
# address: Snäckliden 13
# location: Sundhammar,
#           Kungälvs kommun
# boarea: 48
#
#
# biarea: 33 m²
# rooms:
#                 6
# plot: 1 590 m² tomt
# price: 2 800 000 kr
# -------------------------
# sold_date: 1 september 2017
# address: Bergåsvägen 16e
# location: Kungälv - Ytterby,
#           Kungälvs kommun
# boarea: 100
# biarea: None
# rooms:
#                 6
# plot: 602 m² tomt
# price: 4 820 000 kr
# -------------------------
# sold_date: 31 augusti 2017
# address: Sjöhåla 170
# location: KÄRNA,
#           Kungälvs kommun
# boarea: 124
#
#
# biarea: 72 m²
# rooms:
#                 6
# plot: 2 035 m² tomt
# price: 3 550 000 kr
# -------------------------
# sold_date: 30 augusti 2017
# address: Duvesjön 308
# location: Romelanda,
#           Kungälvs kommun
# boarea: 121
# biarea: None
# rooms:
#                 6
# plot: 916 m² tomt
# price: 3 295 000 kr
# -------------------------
# sold_date: 29 augusti 2017
# address: Hermelingatan 11
# location: Olseröd,
#           Kungälvs kommun
# boarea: 126
# biarea: None
# rooms:
#                 6
# plot: 548 m² tomt
# price: 5 300 000 kr
# -------------------------
# sold_date: 28 augusti 2017
# address: Flädervägen 14
# location: Bohuslän,
#           Kungälvs kommun
# boarea: 105
# biarea: None
# rooms:
#                 6
# plot: 476 m² tomt
# price: 3 450 000 kr
# -------------------------
# sold_date: 24 augusti 2017
# address: Solberga 900
# location: Kode,
#           Kungälvs kommun
# boarea: 123
# biarea: None
# rooms:
#                 6
# plot: 1 107 m² tomt
# price: 2 500 000 kr
# -------------------------
# file_name: kungalv_slutpriser/kungalv_slutpris_page_31.html
# sold_date: 8 oktober 2016
# address: Solvagnsgatan 28
# location: Ytterby - Stället,
#           Kungälvs kommun
# boarea: 164
#
#
# biarea: 12 m²
# rooms:
#                 6
# plot: 441 m² tomt
# price: 4 725 000 kr
# -------------------------
# sold_date: 7 oktober 2016
# address: Kärrhed 240
# location: Kärna,
#           Kungälvs kommun
# boarea: 48
# biarea: None
# rooms:
#                 6
# plot: 2 760 m² tomt
# price: 2 100 000 kr
# -------------------------
# sold_date: 5 oktober 2016
# address: Sköldgatan 5
# location: Ytterby Stället,
#           Kungälvs kommun
# boarea: 137
#
#
# biarea: 8 m²
# rooms:
#                 6
# plot: 437 m² tomt
# price: 4 400 000 kr
# -------------------------
# sold_date: 30 september 2016
# address: Signehög 210
# location: Kungälv - Romelanda,
#           Kungälvs kommun
# boarea: 142
# biarea: None
# rooms:
#                 6
# plot: 945 m² tomt
# price: 3 100 000 kr
# -------------------------
# sold_date: 29 september 2016
# address: Hallsbrovägen 3
# location: Kärna,
#           Kungälvs kommun
# boarea: 60
# biarea: None
# rooms:
#                 6
# plot: 1 801 m² tomt
# price: 1 150 000 kr
# -------------------------
# sold_date: 29 september 2016
# address: Lökebergsvägen 41
# location: Lökeberg,
#           Kungälvs kommun
# boarea: 44
#
#
# biarea: 6 m²
# rooms:
#                 6
# plot: 1 511 m² tomt
# price: 2 550 000 kr
# -------------------------
# sold_date: 29 september 2016
# address: Domsvägen 3
# location: Ytterby,
#           Kungälvs kommun
# boarea: 157
#
#
# biarea: 99 m²
# rooms:
#                 6
# plot: 921 m² tomt
# price: 4 850 000 kr
# -------------------------
# sold_date: 25 september 2016
# address: Plogvägen 180
# location: Kungälv,
#           Kungälvs kommun
# boarea: 106
# biarea: 5 m²
# rooms:
#                 6
# plot: 338 m² tomt
# price: 4 300 000 kr
# -------------------------
# sold_date: 23 september 2016
# address: Bärtas väg 13
# location: Ödsmålsmosse,
#           Kungälvs kommun
# boarea: 75
# biarea: None
# rooms:
#                 6
# plot: 1 418 m² tomt
# price: 3 250 000 kr
# -------------------------
# sold_date: 23 september 2016
# address: Onyxvägen 19
# location: Kode,
#           Kungälvs kommun
# boarea: 155
# biarea: None
# rooms:
#                 6
# plot: 557 m² tomt
# price: 4 750 000 kr
# -------------------------
# sold_date: 17 september 2016
# address: Lingonvägen 38
# location: Centralt,
#           Kungälvs kommun
# boarea: 127
# biarea: None
# rooms:
#                 6
# plot: 428 m² tomt
# price: 4 560 000 kr
# -------------------------
# sold_date: 14 september 2016
# address: Djupuddsvägen 20
# location: Marstrand - Instön,
#           Kungälvs kommun
# boarea: 112
# biarea: None
# rooms:
#                 6
# plot: 1 438 m² tomt
# price: 3 500 000 kr
# -------------------------
# sold_date: 13 september 2016
# address: Kastellegårdsgatan 47
# location: KUNGÄLV,
#           Kungälvs kommun
# boarea: 116
#
#
# biarea: 50 m²
# rooms:
#                 6
# plot: 938 m² tomt
# price: 3 425 000 kr
# -------------------------
# sold_date: 10 september 2016
# address: Rosenstensvägen 41
# location: Kode,
#           Kungälvs kommun
# boarea: 135
# biarea: None
# rooms:
#                 6
# plot: 193 m² tomt
# price: 2 800 000 kr
# -------------------------
# sold_date: 9 september 2016
# address: Annas väg 25
# location: Kovikshamn,
#           Kungälvs kommun
# boarea: 62
#
#
# biarea: 22 m²
# rooms:
#                 6
# plot: 1 026 m² tomt
# price: 2 730 000 kr
# -------------------------
# sold_date: 2 september 2016
# address: Knaverstad-Ryr 580
# location: Aröd,
#           Kungälvs kommun
# boarea: 158
#
#
# biarea: 4 m²
# rooms:
#                 6
# plot: 1 012 m² tomt
# price: 2 840 000 kr
# -------------------------
# sold_date: 1 september 2016
# address: Solrosvägen 12
# location: Kärna,
#           Kungälvs kommun
# boarea: 135
#
#
# biarea: 96 m²
# rooms:
#                 6
# plot: 818 m² tomt
# price: 3 325 000 kr
# -------------------------
# sold_date: 30 augusti 2016
# address: Bergåsvägen 16 C-D
# location: Ytterby,
#           Kungälvs kommun
# boarea: 175,5
# biarea: None
# rooms:
#                 6
# plot: 600 m² tomt
# price: 4 700 000 kr
# -------------------------
# sold_date: 28 augusti 2016
# address: Åkerhög 310
# location: Vedhall - Åkerhög,
#           Kungälvs kommun
# boarea: 65
# biarea: None
# rooms:
#                 6
# plot: 1 500 m² tomt
# price: 2 050 000 kr
# -------------------------
# sold_date: 26 augusti 2016
# address: Skårby Mosse 870
# location: Bohuslän,
#           Kungälvs kommun
# boarea: 147
#
#
# biarea: 50 m²
# rooms:
#                 6
# plot: 3 073 m² tomt
# price: 4 000 000 kr
# -------------------------
# sold_date: 25 augusti 2016
# address: Rörtången 126
# location: Rörtången,
#           Kungälvs kommun
# boarea: 170
#
#
# biarea: 20 m²
# rooms:
#                 6
# plot: 1 638 m² tomt
# price: 8 700 000 kr
# -------------------------
# sold_date: 24 augusti 2016
# address: Sjöhåla Strandväg 14
# location: Kovikshamn,
#           Kungälvs kommun
# boarea: 164
# biarea: None
# rooms:
#                 6
# plot: 1 075 m² tomt
# price: 5 700 000 kr
# -------------------------
# sold_date: 20 augusti 2016
# address: Tegskiftegatan 20
# location: YTTERBY,
#           Kungälvs kommun
# boarea: 102
#
#
# biarea: 102 m²
# rooms:
#                 6
# plot: 969 m² tomt
# price: 3 550 000 kr
# -------------------------
# sold_date: 18 augusti 2016
# address: Bärtas väg 23
# location: Ödsmålsmosse,
#           Kungälvs kommun
# boarea: 51
#
#
# biarea: 20 m²
# rooms:
#                 6
# plot: 1 380 m² tomt
# price: 3 025 000 kr
# -------------------------
# sold_date: 15 augusti 2016
# address: Långgatan 8
# location: Marstrandsön,
#           Kungälvs kommun
# boarea: 244
#
#
# biarea: 50 m²
# rooms:
#                 6
# plot: 318 m² tomt
# price: 11 250 000 kr
# -------------------------
# sold_date: 14 augusti 2016
# address: Instölid 40
# location: Marstrand-Instön,
#           Kungälvs kommun
# boarea: 70
# biarea: None
# rooms:
#                 6
# plot: 1 010 m² tomt
# price: 3 500 000 kr
# -------------------------
# sold_date: 12 augusti 2016
# address: Åsebyberg 847
# location: KODE,
#           Kungälvs kommun
# boarea: 120
#
#
# biarea: 15 m²
# rooms:
#                 6
# plot: 1 163 m² tomt
# price: 3 300 000 kr
# -------------------------
# sold_date: 8 augusti 2016
# address: Bremnäs 305
# location: LYCKE,
#           Kungälvs kommun
# boarea: 115
# biarea: None
# rooms:
#                 6
# plot: 1 979 m² tomt
# price: 4 000 000 kr
# -------------------------
# sold_date: 28 juli 2016
# address: Tröskvägen 256
# location: Ullstorp,
#           Kungälvs kommun
# boarea: 149
#
#
# biarea: 9 m²
# rooms:
#                 6
# plot: 440 m² tomt
# price: 5 355 000 kr
# -------------------------
# sold_date: 27 juli 2016
# address: Östra röd 248
# location: HARESTAD,
#           Kungälvs kommun
# boarea: 144
# biarea: None
# rooms:
#                 6
# plot: 2 006 m² tomt
# price: 4 200 000 kr
# -------------------------
# sold_date: 25 juli 2016
# address: Stenstavägen 21
# location: Tjuvkil,
#           Kungälvs kommun
# boarea: 140
#
#
# biarea: 58 m²
# rooms:
#                 6
# plot: 1 223 m² tomt
# price: 6 000 000 kr
# -------------------------
# sold_date: 20 juli 2016
# address: Rombacka 180
# location: Kareby,
#           Kungälvs kommun
# boarea: 53
#
#
# biarea: 7 m²
# rooms:
#                 6
# plot: 2 031 m² tomt
# price: 1 075 000 kr
# -------------------------
# sold_date: 18 juli 2016
# address: Vedbackavägen 4 A + B
# location: Rödbo,
#           Kungälvs kommun
# boarea: 254
#
#
# biarea: 42 m²
# rooms:
#                 6
# plot: 1 046 m² tomt
# price: 2 900 000 kr
# -------------------------
# sold_date: 15 juli 2016
# address: Lefstad 110
# location: Kärna,
#           Kungälvs kommun
# boarea: 182
# biarea: None
# rooms:
#                 6
# plot: 2 630 m² tomt
# price: 2 600 000 kr
# -------------------------
# sold_date: 15 juli 2016
# address: Gunneröd 290
# location: Lycke,
#           Kungälvs kommun
# boarea: 132
#
#
# biarea: 39 m²
# rooms:
#                 6
# plot: 2 125 m² tomt
# price: 2 300 000 kr
# -------------------------
# sold_date: 13 juli 2016
# address: Duvesjön 228
# location: Duvesjön,
#           Kungälvs kommun
# boarea: 121
#
#
# biarea: 37 m²
# rooms:
#                 6
# plot: 1 150 m² tomt
# price: 3 400 000 kr
# -------------------------
# sold_date: 11 juli 2016
# address: Violgatan 7
# location: Ytterby,
#           Kungälvs kommun
# boarea: 139
#
#
# biarea: 36 m²
# rooms:
#                 6
# plot: 588 m² tomt
# price: 4 200 000 kr
# -------------------------
# sold_date: 10 juli 2016
# address: Instölid 65
# location: Marstrand-Instön,
#           Kungälvs kommun
# boarea: 60
# biarea: None
# rooms:
#                 6
# plot: 1 012 m² tomt
# price: 3 320 000 kr
# -------------------------
# sold_date: 8 juli 2016
# address: Rörtången 103
# location: Rörtången,
#           Kungälvs kommun
# boarea: 162
#
#
# biarea: 62 m²
# rooms:
#                 6
# plot: 1 015 m² tomt
# price: 7 250 000 kr
# -------------------------
# sold_date: 6 juli 2016
# address: Nereby 360
# location: Kärna - Harestad,
#           Kungälvs kommun
# boarea: 120
#
#
# biarea: 40 m²
# rooms:
#                 6
# plot: 1 149 m² tomt
# price: 3 100 000 kr
# -------------------------
# sold_date: 6 juli 2016
# address: Skår 260
# location: Romelanda Skår,
#           Kungälvs kommun
# boarea: 31
# biarea: None
# rooms:
#                 6
# plot: 785 m² tomt
# price: 250 000 kr
# -------------------------
# sold_date: 5 juli 2016
# address: Mariebergsvägen 130
# location: Östra Kungälv - Marieberg,
#           Kungälvs kommun
# boarea: 230
#
#
# biarea: 41 m²
# rooms:
#                 6
# plot: 2 100 m² tomt
# price: 5 520 000 kr
# -------------------------
# sold_date: 5 juli 2016
# address: Lerlycke 240
# location: Lerlycke - Kärna,
#           Kungälvs kommun
# boarea: 129
#
#
# biarea: 44 m²
# rooms:
#                 6
# plot: 12 665 m² tomt
# price: 4 420 000 kr
# -------------------------
# sold_date: 4 juli 2016
# address: Rörtången 295
# location: Kode,
#           Kungälvs kommun
# boarea: 90
#
#
# biarea: 15 m²
# rooms:
#                 6
# plot: 1 795 m² tomt
# price: 5 275 000 kr
# -------------------------
# sold_date: 4 juli 2016
# address: Dannemarksgatan 45
# location: Tega,
#           Kungälvs kommun
# boarea: 140
# biarea: None
# rooms:
#                 6
# plot: 1 072 m² tomt
# price: 4 850 000 kr
# -------------------------
# sold_date: 4 juli 2016
# address: Krokens Väg 11
# location: Tjuvkil,
#           Kungälvs kommun
# boarea: 148
# biarea: None
# rooms:
#                 6
# plot: 1 155 m² tomt
# price: 6 000 000 kr
# -------------------------
# sold_date: 1 juli 2016
# address: Briljantvägen 9
# location: KODE,
#           Kungälvs kommun
# boarea: 125
# biarea: None
# rooms:
#                 6
# plot: 350 m² tomt
# price: 3 200 000 kr
# -------------------------
# sold_date: 28 juni 2016
# address: Rörmossevägen 180
# location: Rörmossen,
#           Kungälvs kommun
# boarea: 110
#
#
# biarea: 135 m²
# rooms:
#                 6
# plot: 1 827 m² tomt
# price: 3 725 000 kr
# -------------------------
# sold_date: 26 juni 2016
# address: Hammar 565
# location: Skäggstorp,
#           Kungälvs kommun
# boarea: 160
# biarea: None
# rooms:
#                 6
# plot: 2 210 m² tomt
# price: 3 000 000 kr
# -------------------------
# sold_date: 22 juni 2016
# address: Byvägen 33
# location: Kode Ödsmål,
#           Kungälvs kommun
# boarea: 58
# biarea: None
# rooms:
#                 6
# plot: 1 871 m² tomt
# price: 2 625 000 kr
# -------------------------
# file_name: kungalv_slutpriser/kungalv_slutpris_page_11.html
# sold_date: 20 april 2021
# address: Gulskärsvägen 21
# location: Tjuvkil,
#           Kungälvs kommun
# boarea: 149
#
#
# biarea: 14 m²
# rooms:
#                 6
# plot: 1 512 m² tomt
# price: 7 400 000 kr
# -------------------------
# sold_date: 20 april 2021
# address: Mårdgatan 4
# location: Olseröd,
#           Kungälvs kommun
# boarea: 124
#
#
# biarea: 45 m²
# rooms:
#                 6
# plot: 1 122 m² tomt
# price: 7 150 000 kr
# -------------------------
# sold_date: 19 april 2021
# address: Lilla Fjellsholmen 22
# location: Lilla Fjellsholmen,
#           Kungälvs kommun
# boarea: 4
# biarea: None
# rooms:
#                 6
# plot: 406 m² tomt
# price: 8 900 000 kr
# -------------------------
# sold_date: 16 april 2021
# address: Lindvägen 8
# location: Ytterby,
#           Kungälvs kommun
# boarea: 244
#
#
# biarea: 72 m²
# rooms:
#                 6
# plot: 1 330 m² tomt
# price: 7 700 000 kr
# -------------------------
# sold_date: 16 april 2021
# address: Stenåldersgatan 41
# location: Ytterby,
#           Kungälvs kommun
# boarea: 120
# biarea: None
# rooms:
#                 6
# plot: 404 m² tomt
# price: 5 350 000 kr
# -------------------------
# sold_date: 16 april 2021
# address: Harkvägen 335
# location: Ullstorp,
#           Kungälvs kommun
# boarea: 131
# biarea: None
# rooms:
#                 6
# plot: None
# price: 4 610 000 kr
# -------------------------
# sold_date: 15 april 2021
# address: Prästvägen 296
# location: Kareby,
#           Kungälvs kommun
# boarea: 187
# biarea: None
# rooms:
#                 6
# plot: 1 434 m² tomt
# price: 8 100 000 kr
# -------------------------
# sold_date: 15 april 2021
# address: Duvesjön 228
# location: Diseröd,
#           Kungälvs kommun
# boarea: 121
#
#
# biarea: 37 m²
# rooms:
#                 6
# plot: 1 150 m² tomt
# price: 4 925 000 kr
# -------------------------
# sold_date: 15 april 2021
# address: Kuskalundsvägen 11
# location: Hålta,
#           Kungälvs kommun
# boarea: 110
#
#
# biarea: 49 m²
# rooms:
#                 6
# plot: 1 227 m² tomt
# price: 4 025 000 kr
# -------------------------
# sold_date: 14 april 2021
# address: Ulvesund 412
# location: Ulvesund,
#           Kungälvs kommun
# boarea: 106
#
#
# biarea: 9 m²
# rooms:
#                 6
# plot: 806 m² tomt
# price: 4 750 000 kr
# -------------------------
# sold_date: 13 april 2021
# address: Mantalsgatan 15
# location: Tega,
#           Kungälvs kommun
# boarea: 110
# biarea: None
# rooms:
#                 6
# plot: 986 m² tomt
# price: 3 725 000 kr
# -------------------------
# sold_date: 13 april 2021
# address: Klintegatan 7
# location: Kungälv - Centrum,
#           Kungälvs kommun
# boarea: 143
#
#
# biarea: 112 m²
# rooms:
#                 6
# plot: 798 m² tomt
# price: 7 750 000 kr
# -------------------------
# sold_date: 12 april 2021
# address: Duvesjön 205
# location: Diseröd,
#           Kungälvs kommun
# boarea: 126
# biarea: None
# rooms:
#                 6
# plot: 1 062 m² tomt
# price: 4 700 000 kr
# -------------------------
# sold_date: 8 april 2021
# address: Nygatan 6
# location: Marstrand - Koön,
#           Kungälvs kommun
# boarea: 90
# biarea: None
# rooms:
#                 6
# plot: 376 m² tomt
# price: 7 500 000 kr
# -------------------------
# sold_date: 8 april 2021
# address: Prästvägen 170
# location: Kareby,
#           Kungälvs kommun
# boarea: 95
#
#
# biarea: 140 m²
# rooms:
#                 6
# plot: 2 868 m² tomt
# price: 3 770 000 kr
# -------------------------
# sold_date: 4 april 2021
# address: Hammarberg 825
# location: Kode,
#           Kungälvs kommun
# boarea: 65
#
#
# biarea: 74 m²
# rooms:
#                 6
# plot: 3 030 m² tomt
# price: 4 350 000 kr
# -------------------------
# sold_date: 2 april 2021
# address: Duvesjön 420
# location: Bohuslän,
#           Kungälvs kommun
# boarea: 127
#
#
# biarea: 10 m²
# rooms:
#                 6
# plot: 834 m² tomt
# price: 5 400 000 kr
# -------------------------
# sold_date: 1 april 2021
# address: Rönnvägen 11
# location: Diseröd,
#           Kungälvs kommun
# boarea: 120
#
#
# biarea: 88 m²
# rooms:
#                 6
# plot: 849 m² tomt
# price: 3 465 000 kr
# -------------------------
# sold_date: 1 april 2021
# address: Toreby mosse 570
# location: Ytterby,
#           Kungälvs kommun
# boarea: 110
#
#
# biarea: 80 m²
# rooms:
#                 6
# plot: 1 375 m² tomt
# price: 2 980 000 kr
# -------------------------
# sold_date: 1 april 2021
# address: Häljeröd 106
# location: Diseröd,
#           Kungälvs kommun
# boarea: 120
#
#
# biarea: 90 m²
# rooms:
#                 6
# plot: 1 734 m² tomt
# price: 3 700 000 kr
# -------------------------
# sold_date: 26 mars 2021
# address: Domsvägen 7B
# location: Centralt Ytterby,
#           Kungälvs kommun
# boarea: 159
#
#
# biarea: 62 m²
# rooms:
#                 6
# plot: 600 m² tomt
# price: 5 500 000 kr
# -------------------------
# sold_date: 25 mars 2021
# address: Grandalen 110
# location: Duvesjön,
#           Kungälvs kommun
# boarea: 65
# biarea: None
# rooms:
#                 6
# plot: 1 121 m² tomt
# price: 2 375 000 kr
# -------------------------
# sold_date: 25 mars 2021
# address: Kroken 142
# location: Harestad,
#           Kungälvs kommun
# boarea:
# biarea: None
# rooms:
#                 6
# plot: 1 175 m² tomt
# price: 3 900 000 kr
# -------------------------
# sold_date: 23 mars 2021
# address: Ekvägen 2
# location: Ytterby,
#           Kungälvs kommun
# boarea: 177
#
#
# biarea: 60 m²
# rooms:
#                 6
# plot: 769 m² tomt
# price: 7 700 000 kr
# -------------------------
# sold_date: 22 mars 2021
# address: Råckeröd 140
# location: Kärna,
#           Kungälvs kommun
# boarea: 66
#
#
# biarea: 20 m²
# rooms:
#                 6
# plot: 2 269 m² tomt
# price: 3 800 000 kr
# -------------------------
# sold_date: 19 mars 2021
# address: Nätstigen 7
# location: Centralt,
#           Kungälvs kommun
# boarea: 120
# biarea: None
# rooms:
#                 6
# plot: 299 m² tomt
# price: 3 900 000 kr
# -------------------------
# sold_date: 18 mars 2021
# address: Hallbjörtorp 492
# location: Kärna,
#           Kungälvs kommun
# boarea: 104
#
#
# biarea: 8 m²
# rooms:
#                 6
# plot: 1 499 m² tomt
# price: 3 900 000 kr
# -------------------------
# sold_date: 18 mars 2021
# address: Dösebacka 130
# location: Diseröd,
#           Kungälvs kommun
# boarea: 123
#
#
# biarea: 41 m²
# rooms:
#                 6
# plot: 4 859 m² tomt
# price: 5 350 000 kr
# -------------------------
# sold_date: 17 mars 2021
# address: Åsgatan 17A
# location: Centrum,
#           Kungälvs kommun
# boarea: 84
#
#
# biarea: 44 m²
# rooms:
#                 6
# plot: 903 m² tomt
# price: 5 620 000 kr
# -------------------------
# sold_date: 17 mars 2021
# address: Tvetgatan 263
# location: Tveten,
#           Kungälvs kommun
# boarea: 100
#
#
# biarea: 50 m²
# rooms:
#                 6
# plot: 138 m² tomt
# price: 3 850 000 kr
# -------------------------
# sold_date: 16 mars 2021
# address: Olserödsgatan 86
# location: Kungälv - Olseröd,
#           Kungälvs kommun
# boarea: 104
# biarea: None
# rooms:
#                 6
# plot: 288 m² tomt
# price: 4 050 000 kr
# -------------------------
# sold_date: 16 mars 2021
# address: Tjuvkil 450
# location: Tjuvkil,
#           Kungälvs kommun
# boarea: 237
#
#
# biarea: 118 m²
# rooms:
#                 6
# plot: 1 434 m² tomt
# price: 3 120 000 kr
# -------------------------
# sold_date: 16 mars 2021
# address: Rondan 19
# location: Rörtången / Ödsmålsmosse,
#           Kungälvs kommun
# boarea: 60
#
#
# biarea: 60 m²
# rooms:
#                 6
# plot: 1 927 m² tomt
# price: 4 400 000 kr
# -------------------------
# sold_date: 16 mars 2021
# address: Åsebyberg 960
# location: Kode,
#           Kungälvs kommun
# boarea: 157
#
#
# biarea: 16 m²
# rooms:
#                 6
# plot: 1 038 m² tomt
# price: 3 850 000 kr
# -------------------------
# sold_date: 16 mars 2021
# address: Ulvegärdegatan 15
# location: Ulvegärde,
#           Kungälvs kommun
# boarea: 140
#
#
# biarea: 96 m²
# rooms:
#                 6
# plot: 1 438 m² tomt
# price: 6 100 000 kr
# -------------------------
# sold_date: 15 mars 2021
# address: Solhultsgatan 27
# location: Komarken,
#           Kungälvs kommun
# boarea: 100
# biarea: None
# rooms:
#                 6
# plot: 560 m² tomt
# price: 3 315 000 kr
# -------------------------
# sold_date: 12 mars 2021
# address: Flateby 480
# location: Harestad,
#           Kungälvs kommun
# boarea: 59
#
#
# biarea: 16 m²
# rooms:
#                 6
# plot: 1 194 m² tomt
# price: 1 600 000 kr
# -------------------------
# sold_date: 11 mars 2021
# address: Björkebacka 114
# location: Kareby,
#           Kungälvs kommun
# boarea: 104
# biarea: None
# rooms:
#                 6
# plot: 996 m² tomt
# price: 5 100 000 kr
# -------------------------
# sold_date: 10 mars 2021
# address: Älvängen 130
# location: Harestad,
#           Kungälvs kommun
# boarea: 317
#
#
# biarea: 71 m²
# rooms:
#                 6
# plot: 1 180 m² tomt
# price: 5 250 000 kr
# -------------------------
# sold_date: 3 mars 2021
# address: Tegskiftegatan 46
# location: Ytterby,
#           Kungälvs kommun
# boarea: 184
#
#
# biarea: 54 m²
# rooms:
#                 6
# plot: 865 m² tomt
# price: 6 850 000 kr
# -------------------------
# sold_date: 2 mars 2021
# address: Sjöhåla strandväg 12
# location: Kärna,
#           Kungälvs kommun
# boarea: 99
# biarea: None
# rooms:
#                 6
# plot: 1 441 m² tomt
# price: 4 350 000 kr
# -------------------------
# sold_date: 27 februari 2021
# address: Skardet 120
# location: Kode,
#           Kungälvs kommun
# boarea: 141
# biarea: None
# rooms:
#                 6
# plot: 2 086 m² tomt
# price: 5 300 000 kr
# -------------------------
# sold_date: 27 februari 2021
# address: Granliden 11
# location: Vedhall,
#           Kungälvs kommun
# boarea: 253
#
#
# biarea: 23,5 m²
# rooms:
#                 6
# plot: 578 m² tomt
# price: 9 200 000 kr
# -------------------------
# sold_date: 25 februari 2021
# address: Önneröd 220
# location: Kärna,
#           Kungälvs kommun
# boarea: 112
# biarea: None
# rooms:
#                 6
# plot: 25 370 m² tomt
# price: 3 000 000 kr
# -------------------------
# sold_date: 24 februari 2021
# address: Duvesjön 232
# location: Duvesjön,
#           Kungälvs kommun
# boarea: 122
# biarea: None
# rooms:
#                 6
# plot: 1 076 m² tomt
# price: 4 725 000 kr
# -------------------------
# sold_date: 22 februari 2021
# address: Annas väg 4
# location: Kärna,
#           Kungälvs kommun
# boarea: 102
#
#
# biarea: 7 m²
# rooms:
#                 6
# plot: 1 158 m² tomt
# price: 3 700 000 kr
# -------------------------
# sold_date: 18 februari 2021
# address: Madängsgatan 13
# location: Centrum,
#           Kungälvs kommun
# boarea: 154
#
#
# biarea: 18 m²
# rooms:
#                 6
# plot: 740 m² tomt
# price: 5 750 000 kr
# -------------------------
# sold_date: 15 februari 2021
# address: Bokvägen 12
# location: Fontin,
#           Kungälvs kommun
# boarea: 175
#
#
# biarea: 35 m²
# rooms:
#                 6
# plot: 635 m² tomt
# price: 7 400 000 kr
# -------------------------
# sold_date: 12 februari 2021
# address: Tullaregatan 3
# location: Marstrandsön,
#           Kungälvs kommun
# boarea: 160
# biarea: None
# rooms:
#                 6
# plot: 333 m² tomt
# price: 15 800 000 kr
# -------------------------
# sold_date: 11 februari 2021
# address: Ulvegärdegatan 15B
# location: Ulvegärde,
#           Kungälvs kommun
# boarea: 80
# biarea: None
# rooms:
#                 6
# plot: 914 m² tomt
# price: 3 700 000 kr
# -------------------------
# file_name: kungalv_slutpriser/kungalv_slutpris_page_07.html
# sold_date: 26 januari 2022
# address: Häroldsgatan 5
# location: Centrum,
#           Kungälvs kommun
# boarea: 141
# biarea: None
# rooms:
#                 6
# plot: 799 m² tomt
# price: 5 700 000 kr
# -------------------------
# sold_date: 25 januari 2022
# address: Långåkersgatan 6
# location: Centralt,
#           Kungälvs kommun
# boarea: 140
#
#
# biarea: 36 m²
# rooms:
#                 6
# plot: 733 m² tomt
# price: 7 000 000 kr
# -------------------------
# sold_date: 24 januari 2022
# address: Västerhöjdsvägen 111
# location: Kärna,
#           Kungälvs kommun
# boarea: 103
# biarea: None
# rooms:
#                 6
# plot: 423 m² tomt
# price: 2 500 000 kr
# -------------------------
# sold_date: 22 januari 2022
# address: Valtersäng 11
# location: Trankärr,
#           Kungälvs kommun
# boarea: 162
# biarea: None
# rooms:
#                 6
# plot: 808 m² tomt
# price: 6 150 000 kr
# -------------------------
# sold_date: 21 januari 2022
# address: Skvaltvägen 3
# location: Diseröd,
#           Kungälvs kommun
# boarea: 180
#
#
# biarea: 145 m²
# rooms:
#                 6
# plot: 1 352 m² tomt
# price: 5 975 000 kr
# -------------------------
# sold_date: 19 januari 2022
# address: Trätäljagatan 7
# location: Iskällan,
#           Kungälvs kommun
# boarea: 142
#
#
# biarea: 142 m²
# rooms:
#                 6
# plot: 1 037 m² tomt
# price: 7 550 000 kr
# -------------------------
# sold_date: 18 januari 2022
# address: Snäckvägen 16
# location: Rörtången/ödsmålsmosse,
#           Kungälvs kommun
# boarea: 62
# biarea: None
# rooms:
#                 6
# plot: 1 801 m² tomt
# price: 3 144 000 kr
# -------------------------
# sold_date: 18 januari 2022
# address: Hemvägen 21
# location: Diseröd,
#           Kungälvs kommun
# boarea: 108
#
#
# biarea: 32 m²
# rooms:
#                 6
# plot: 384 m² tomt
# price: 4 050 000 kr
# -------------------------
# sold_date: 11 januari 2022
# address: Ödsmål 540
# location: Rörtången,
#           Kungälvs kommun
# boarea: 65
#
#
# biarea: 31 m²
# rooms:
#                 6
# plot: 916 m² tomt
# price: 3 850 000 kr
# -------------------------
# sold_date: 8 januari 2022
# address: Lagvägen 17
# location: Ytterby,
#           Kungälvs kommun
# boarea: 164
# biarea: None
# rooms:
#                 6
# plot: 597 m² tomt
# price: 5 850 000 kr
# -------------------------
# sold_date: 7 januari 2022
# address: Mariebergsliden 5
# location: Öster,
#           Kungälvs kommun
# boarea: 277
#
#
# biarea: 91 m²
# rooms:
#                 6
# plot: 589 m² tomt
# price: 10 000 000 kr
# -------------------------
# sold_date: 30 december 2021
# address: Älvängen 180
# location: Harestad,
#           Kungälvs kommun
# boarea: 75
#
#
# biarea: 58 m²
# rooms:
#                 6
# plot: 1 631 m² tomt
# price: 4 150 000 kr
# -------------------------
# sold_date: 22 december 2021
# address: Mossvägen 24
# location: Hålta,
#           Kungälvs kommun
# boarea: 72
# biarea: None
# rooms:
#                 6
# plot: 1 068 m² tomt
# price: 3 500 000 kr
# -------------------------
# sold_date: 21 december 2021
# address: Galeasgatan 6
# location: Komarken,
#           Kungälvs kommun
# boarea: 100
# biarea: None
# rooms:
#                 6
# plot: 296 m² tomt
# price: 4 000 000 kr
# -------------------------
# sold_date: 14 december 2021
# address: Stenåldersgatan 50
# location: Stället,
#           Kungälvs kommun
# boarea: 110
# biarea: None
# rooms:
#                 6
# plot: 221 m² tomt
# price: 4 900 000 kr
# -------------------------
# sold_date: 9 december 2021
# address: Munkegärdegatan  310
# location: Munkegärde,
#           Kungälvs kommun
# boarea: 146
# biarea: None
# rooms:
#                 6
# plot: 622 m² tomt
# price: 6 110 000 kr
# -------------------------
# sold_date: 8 december 2021
# address: Stora Ryr 310
# location: Tjuvkil/ Lycke,
#           Kungälvs kommun
# boarea: 106
#
#
# biarea: 55 m²
# rooms:
#                 6
# plot: 1 239 m² tomt
# price: 3 695 000 kr
# -------------------------
# sold_date: 7 december 2021
# address: Mårdgatan 11
# location: Klöverbacken - Olseröd,
#           Kungälvs kommun
# boarea: 166
#
#
# biarea: 12 m²
# rooms:
#                 6
# plot: 367 m² tomt
# price: 6 310 000 kr
# -------------------------
# sold_date: 6 december 2021
# address: Ulvebackegatan 3
# location: Ulvegärde,
#           Kungälvs kommun
# boarea: 129
#
#
# biarea: 44 m²
# rooms:
#                 6
# plot: 927 m² tomt
# price: 4 600 000 kr
# -------------------------
# sold_date: 3 december 2021
# address: Plogvägen 187
# location: Ullstorp,
#           Kungälvs kommun
# boarea: 122
#
#
# biarea: 6 m²
# rooms:
#                 6
# plot: 406 m² tomt
# price: 5 600 000 kr
# -------------------------
# sold_date: 3 december 2021
# address: Galärgatan 1
# location: Centralt vid älven,
#           Kungälvs kommun
# boarea: 104
#
#
# biarea: 4 m²
# rooms:
#                 6
# plot: 762 m² tomt
# price: 3 900 000 kr
# -------------------------
# sold_date: 1 december 2021
# address: Korpedalsvägen 13
# location: Aröd/Timmervik,
#           Kungälvs kommun
# boarea: 47
#
#
# biarea: 40 m²
# rooms:
#                 6
# plot: 1 179 m² tomt
# price: 2 850 000 kr
# -------------------------
# sold_date: 30 november 2021
# address: Grindstolpen 21
# location: Ytterby,
#           Kungälvs kommun
# boarea: 76,1
# biarea: None
# rooms:
#                 6
# plot: None
# price: 3 950 000 kr
# -------------------------
# sold_date: 29 november 2021
# address: Hanekullen 200
# location: Kareby,
#           Kungälvs kommun
# boarea: 114
# biarea: None
# rooms:
#                 6
# plot: 1 673 m² tomt
# price: 4 200 000 kr
# -------------------------
# sold_date: 28 november 2021
# address: Fontinvägen 13
# location: Bohuslän,
#           Kungälvs kommun
# boarea: 120
#
#
# biarea: 110 m²
# rooms:
#                 6
# plot: 1 167 m² tomt
# price: 6 960 500 kr
# -------------------------
# sold_date: 26 november 2021
# address: Kyrkeby 300
# location: Harestad,
#           Kungälvs kommun
# boarea: 114
#
#
# biarea: 117 m²
# rooms:
#                 6
# plot: 1 402 m² tomt
# price: 4 170 000 kr
# -------------------------
# sold_date: 25 november 2021
# address: Parkgatan 21
# location: Marstrand - Koön,
#           Kungälvs kommun
# boarea: 113
#
#
# biarea: 76 m²
# rooms:
#                 6
# plot: 592 m² tomt
# price: 6 100 000 kr
# -------------------------
# sold_date: 25 november 2021
# address: Bäckgatan 38
# location: Centrum,
#           Kungälvs kommun
# boarea: 108
#
#
# biarea: 60 m²
# rooms:
#                 6
# plot: 607 m² tomt
# price: 6 670 000 kr
# -------------------------
# sold_date: 23 november 2021
# address: Bärtas väg 7
# location: Kode,
#           Kungälvs kommun
# boarea: 53
# biarea: None
# rooms:
#                 6
# plot: 1 792 m² tomt
# price: 2 950 000 kr
# -------------------------
# sold_date: 18 november 2021
# address: Lundby 380
# location: Kareby,
#           Kungälvs kommun
# boarea: 140
# biarea: None
# rooms:
#                 6
# plot: 1 818 m² tomt
# price: 5 200 000 kr
# -------------------------
# sold_date: 17 november 2021
# address: Nygatan 36
# location: Marstrand,
#           Kungälvs kommun
# boarea: 118
#
#
# biarea: 30 m²
# rooms:
#                 6
# plot: 146 m² tomt
# price: 5 900 000 kr
# -------------------------
# sold_date: 17 november 2021
# address: Hammarberg 840
# location: Kode,
#           Kungälvs kommun
# boarea: 82
#
#
# biarea: 14 m²
# rooms:
#                 6
# plot: 1 893 m² tomt
# price: 3 420 000 kr
# -------------------------
# sold_date: 16 november 2021
# address: Duvesjön 360
# location: Duvesjön,
#           Kungälvs kommun
# boarea: 109,6
# biarea: None
# rooms:
#                 6
# plot: 968 m² tomt
# price: 4 600 000 kr
# -------------------------
# sold_date: 15 november 2021
# address: Vallgatan 3
# location: Kungälv - Centralt,
#           Kungälvs kommun
# boarea: 65
#
#
# biarea: 61 m²
# rooms:
#                 6
# plot: 495 m² tomt
# price: 5 800 000 kr
# -------------------------
# sold_date: 12 november 2021
# address: Vallby 210
# location: Kode,
#           Kungälvs kommun
# boarea: 70
# biarea: None
# rooms:
#                 6
# plot: 1 260 m² tomt
# price: 2 550 000 kr
# -------------------------
# sold_date: 12 november 2021
# address: Dotorp 470
# location: Kärna,
#           Kungälvs kommun
# boarea: 127
# biarea: None
# rooms:
#                 6
# plot: 18 448 m² tomt
# price: 6 495 000 kr
# -------------------------
# sold_date: 11 november 2021
# address: Prästvägen
# location: Bohuslän,
#           Kungälvs kommun
# boarea:
# biarea: None
# rooms:
#                 6
# plot: 24 755 m² tomt
# price: 1 725 000 kr
# -------------------------
# sold_date: 10 november 2021
# address: Bremnäs 400
# location: Lycke,
#           Kungälvs kommun
# boarea: 130
# biarea: None
# rooms:
#                 6
# plot: 2 562 m² tomt
# price: 5 800 000 kr
# -------------------------
# sold_date: 10 november 2021
# address: Hammarhöjden 680
# location: Kode,
#           Kungälvs kommun
# boarea: 100
# biarea: None
# rooms:
#                 6
# plot: 1 059 m² tomt
# price: 3 650 000 kr
# -------------------------
# sold_date: 5 november 2021
# address: Stenhålt 124
# location: Romelanda,
#           Kungälvs kommun
# boarea: 163
# biarea: None
# rooms:
#                 6
# plot: 1 668 m² tomt
# price: 5 600 000 kr
# -------------------------
# sold_date: 4 november 2021
# address: Veneröd 430
# location: Hålta,
#           Kungälvs kommun
# boarea: 92
# biarea: None
# rooms:
#                 6
# plot: 1 376 m² tomt
# price: 3 825 000 kr
# -------------------------
# sold_date: 4 november 2021
# address: Poppelvägen 1
# location: Diseröd,
#           Kungälvs kommun
# boarea: 138
# biarea: None
# rooms:
#                 6
# plot: 788 m² tomt
# price: 4 300 000 kr
# -------------------------
# sold_date: 3 november 2021
# address: Hammarhöjden 695
# location: Kode,
#           Kungälvs kommun
# boarea: 92
# biarea: None
# rooms:
#                 6
# plot: 1 053 m² tomt
# price: 3 600 000 kr
# -------------------------
# sold_date: 3 november 2021
# address: Grindklykan 7
# location: Grinden,
#           Kungälvs kommun
# boarea: 114
#
#
# biarea: 7 m²
# rooms:
#                 6
# plot: 392 m² tomt
# price: 5 095 000 kr
# -------------------------
# sold_date: 30 oktober 2021
# address: Oxelvägen 24
# location: Diseröd,
#           Kungälvs kommun
# boarea: 139
# biarea: None
# rooms:
#                 6
# plot: 404 m² tomt
# price: 4 000 000 kr
# -------------------------
# sold_date: 30 oktober 2021
# address: Granliden 9
# location: Vedhall,
#           Kungälvs kommun
# boarea: 181
#
#
# biarea: 25 m²
# rooms:
#                 6
# plot: 678 m² tomt
# price: 9 550 000 kr
# -------------------------
# sold_date: 29 oktober 2021
# address: Dalen 150
# location: Kärna,
#           Kungälvs kommun
# boarea: 154
# biarea: None
# rooms:
#                 6
# plot: 1 052 m² tomt
# price: 5 065 000 kr
# -------------------------
# sold_date: 28 oktober 2021
# address: Östra gatan 43
# location: Bohuslän,
#           Kungälvs kommun
# boarea: 134
#
#
# biarea: 31 m²
# rooms:
#                 6
# plot: 1 403,6 m² tomt
# price: 5 600 000 kr
# -------------------------
# sold_date: 27 oktober 2021
# address: Hamngatan 1
# location: Centralt vid älven,
#           Kungälvs kommun
# boarea: 136
#
#
# biarea: 83 m²
# rooms:
#                 6
# plot: 617 m² tomt
# price: 6 010 000 kr
# -------------------------
# sold_date: 26 oktober 2021
# address: Kaprifolvägen 6
# location: Kärna,
#           Kungälvs kommun
# boarea: 128
# biarea: None
# rooms:
#                 6
# plot: 524 m² tomt
# price: 4 800 000 kr
# -------------------------
# file_name: kungalv_slutpriser/kungalv_slutpris_page_06.html
# sold_date: 24 april 2022
# address: Staby 375
# location: Kärna,
#           Kungälvs kommun
# boarea: 129
# biarea: None
# rooms:
#                 6
# plot: 1 558 m² tomt
# price: 5 400 000 kr
# -------------------------
# sold_date: 24 april 2022
# address: Granvägen 7
# location: Ytterby,
#           Kungälvs kommun
# boarea: 100
#
#
# biarea: 54 m²
# rooms:
#                 6
# plot: 623 m² tomt
# price: 5 300 000 kr
# -------------------------
# sold_date: 22 april 2022
# address: Årsnäs 460
# location: Kungälv - Årsnäs,
#           Kungälvs kommun
# boarea: 40
# biarea: None
# rooms:
#                 6
# plot: 2 393 m² tomt
# price: 3 600 000 kr
# -------------------------
# sold_date: 16 april 2022
# address: Trankärr 223
# location: Trankärr,
#           Kungälvs kommun
# boarea: 6
# biarea: None
# rooms:
#                 6
# plot: 958 m² tomt
# price: 5 850 000 kr
# -------------------------
# sold_date: 14 april 2022
# address: Marieberg 210
# location: Kungälv,
#           Kungälvs kommun
# boarea: 120
#
#
# biarea: 34 m²
# rooms:
#                 6
# plot: 3 245 m² tomt
# price: 3 150 000 kr
# -------------------------
# sold_date: 14 april 2022
# address: Dotorp 260
# location: Kungälv - Kärna,
#           Kungälvs kommun
# boarea: 162
#
#
# biarea: 9 m²
# rooms:
#                 6
# plot: 2 003 m² tomt
# price: 4 775 000 kr
# -------------------------
# sold_date: 13 april 2022
# address: Högalidsgatan 12
# location: Centralt vid älven,
#           Kungälvs kommun
# boarea: 139
#
#
# biarea: 72 m²
# rooms:
#                 6
# plot: 816 m² tomt
# price: 6 450 000 kr
# -------------------------
# ...
# sold_date: 30 augusti 2018
# address: Klintegatan 17
# location: Centralt - Kungälv,
#           Kungälvs kommun
# boarea: 125
#
#
# biarea: 51 m²
# rooms:
#                 6
# plot: 704 m² tomt
# price: 7 350 000 kr
# -------------------------
# sold_date: 30 augusti 2018
# address: Stenåldersgatan 53
# location: Ytterby - Stället,
#           Kungälvs kommun
# boarea: 107
# biarea: None
# rooms:
#                 6
# plot: 381 m² tomt
# price: 4 050 000 kr
# -------------------------
# sold_date: 29 augusti 2018
# address: Grepvägen 391
# location: Ullstorp,
#           Kungälvs kommun
# boarea: 121
#
#
# biarea: 7 m²
# rooms:
#                 6
# plot: 431 m² tomt
# price: 4 850 000 kr
# -------------------------
# sold_date: 29 augusti 2018
# address: Duvesjön 310
# location: Duvesjön,
#           Kungälvs kommun
# boarea: 101
# biarea: None
# rooms:
#                 6
# plot: 1 454 m² tomt
# price: 2 800 000 kr
# -------------------------
# sold_date: 29 augusti 2018
# address: Torsby 132
# location: Kärna,
#           Kungälvs kommun
# boarea: 169
# biarea: None
# rooms:
#                 6
# plot: 1 731 m² tomt
# price: 4 550 000 kr
# -------------------------
# sold_date: 25 augusti 2018
# address: Kristinedalsgatan 7
# location: Centrum,
#           Kungälvs kommun
# boarea: 178
#
#
# biarea: 85 m²
# rooms:
#                 6
# plot: 857 m² tomt
# price: 7 125 000 kr
# -------------------------
# sold_date: 24 augusti 2018
# address: Åsebyberg 745
# location: Åsebyberg,
#           Kungälvs kommun
# boarea: 110
# biarea: None
# rooms:
#                 6
# plot: 1 776 m² tomt
# price: 1 130 000 kr
# -------------------------
# sold_date: 24 augusti 2018
# address: Korpvägen 259
# location: KUNGÄLV,
#           Kungälvs kommun
# boarea: 139
#
#
# biarea: 18 m²
# rooms:
#                 6
# plot: 437 m² tomt
# price: 5 500 000 kr
# -------------------------
# sold_date: 17 augusti 2018
# address: Ställets bygata 76
# location: YTTERBY,
#           Kungälvs kommun
# boarea: 147
# biarea: None
# rooms:
#                 6
# plot: 1 070 m² tomt
# price: 4 925 000 kr
# -------------------------
# sold_date: 15 augusti 2018
# address: Skeppsholmsgatan 2
# location: Centrum,
#           Kungälvs kommun
# boarea: 121
# biarea: None
# rooms:
#                 6
# plot: 913 m² tomt
# price: 6 300 000 kr
# -------------------------
# sold_date: 10 augusti 2018
# address: Jägersberg 244
# location: Kode,
#           Kungälvs kommun
# boarea: 120
# biarea: None
# rooms:
#                 6
# plot: 2 003 m² tomt
# price: 3 850 000 kr
# -------------------------
# sold_date: 9 augusti 2018
# address: Hammarhöjden 670
# location: Kode,
#           Kungälvs kommun
# boarea: 100
#
#
# biarea: 47 m²
# rooms:
#                 6
# plot: 1 090 m² tomt
# price: 3 230 000 kr
# -------------------------
# sold_date: 29 juli 2018
# address: Saltskärsvägen 10
# location: Tjuvkil,
#           Kungälvs kommun
# boarea: 64
# biarea: None
# rooms:
#                 6
# plot: 3 440 m² tomt
# price: 2 300 000 kr
# -------------------------
# sold_date: 26 juli 2018
# address: Duvesjön 313
# location: Duvesjön,
#           Kungälvs kommun
# boarea: 87
# biarea: None
# rooms:
#                 6
# plot: 1 191 m² tomt
# price: 3 300 000 kr
# -------------------------
# sold_date: 18 juli 2018
# address: Byvägen 18
# location: Ödsmåls mosse/Rörtången,
#           Kungälvs kommun
# boarea: 60
#
#
# biarea: 42 m²
# rooms:
#                 6
# plot: 1 509 m² tomt
# price: 1 850 000 kr
# -------------------------
# sold_date: 17 juli 2018
# address: Guntorpsvägen 2
# location: Kode,
#           Kungälvs kommun
# boarea: 129
#
#
# biarea: 70 m²
# rooms:
#                 6
# plot: 734 m² tomt
# price: 3 150 000 kr
# -------------------------
# sold_date: 12 juli 2018
# address: Tjuvkil 510
# location: Tjuvkil,
#           Kungälvs kommun
# boarea: 90
#
#
# biarea: 98 m²
# rooms:
#                 6
# plot: 2 575 m² tomt
# price: 2 550 000 kr
# -------------------------
# sold_date: 10 juli 2018
# address: Lundby 475
# location: Kareby,
#           Kungälvs kommun
# boarea: 141
# biarea: None
# rooms:
#                 6
# plot: 2 024 m² tomt
# price: 4 680 000 kr
# -------------------------
# sold_date: 9 juli 2018
# address: Gunneröd 200
# location: Lycke,
#           Kungälvs kommun
# boarea: 58
#
#
# biarea: 25 m²
# rooms:
#                 6
# plot: 789 m² tomt
# price: 2 400 000 kr
# -------------------------
# file_name: kungalv_slutpriser/kungalv_slutpris_page_32.html
# sold_date: 21 juni 2016
# address: Alelyckans väg 23
# location: Kode,
#           Kungälvs kommun
# boarea: 80
#
#
# biarea: 100 m²
# rooms:
#                 6
# plot: 37 080 m² tomt
# price: 9 000 000 kr
# -------------------------
# sold_date: 19 juni 2016
# address: Krokens Väg 16
# location: Tjuvkil,
#           Kungälvs kommun
# boarea: 67
#
#
# biarea: 50 m²
# rooms:
#                 6
# plot: 1 590 m² tomt
# price: 3 250 000 kr
# -------------------------
# sold_date: 14 juni 2016
# address: Stenstavägen 1
# location: Tjuvkil,
#           Kungälvs kommun
# boarea: 125
#
#
# biarea: 32 m²
# rooms:
#                 6
# plot: 800 m² tomt
# price: 3 850 000 kr
# -------------------------
# sold_date: 14 juni 2016
# address: Instölid 82
# location: MARSTRAND,
#           Kungälvs kommun
# boarea: 36
#
#
# biarea: 10 m²
# rooms:
#                 6
# plot: 902 m² tomt
# price: 2 320 000 kr
# -------------------------
# sold_date: 10 juni 2016
# address: Rönnvägen 7
# location: Romelanda Diseröd,
#           Kungälvs kommun
# boarea: 122
#
#
# biarea: 82 m²
# rooms:
#                 6
# plot: 796 m² tomt
# price: 3 300 000 kr
# -------------------------
# sold_date: 8 juni 2016
# address: Valler 300
# location: Valler - Romelanda,
#           Kungälvs kommun
# boarea: 185
#
#
# biarea: 52 m²
# rooms:
#                 6
# plot: 2 497 m² tomt
# price: 3 450 000 kr
# -------------------------
# sold_date: 6 juni 2016
# address: Svartedalen 220
# location: Svartedalen-Björkärr,
#           Kungälvs kommun
# boarea: 30
# biarea: None
# rooms:
#                 6
# plot: 1 774 m² tomt
# price: 685 000 kr
# -------------------------
# sold_date: 4 juni 2016
# address: Fontinvägen 42
# location: Centrum,
#           Kungälvs kommun
# boarea: 118
#
#
# biarea: 7 m²
# rooms:
#                 6
# plot: 440 m² tomt
# price: 5 100 000 kr
# -------------------------
# sold_date: 3 juni 2016
# address: Bokvägen 10
# location: Centrum,
#           Kungälvs kommun
# boarea: 125
#
#
# biarea: 27 m²
# rooms:
#                 6
# plot: 635 m² tomt
# price: 4 400 000 kr
# -------------------------
# sold_date: 2 juni 2016
# address: Hermansby 150
# location: Kärna,
#           Kungälvs kommun
# boarea: 123
#
#
# biarea: 97 m²
# rooms:
#                 6
# plot: 2 397 m² tomt
# price: 4 070 000 kr
# -------------------------
# sold_date: 1 juni 2016
# address: Duvesjön 348
# location: Kungälv -Duvesjön,
#           Kungälvs kommun
# boarea: 160
#
#
# biarea: 26 m²
# rooms:
#                 6
# plot: 1 927 m² tomt
# price: 5 200 000 kr
# -------------------------
# sold_date: 31 maj 2016
# address: Granndalen 12
# location: Lycke,
#           Kungälvs kommun
# boarea: 65
# biarea: None
# rooms:
#                 6
# plot: 1 217 m² tomt
# price: 2 050 000 kr
# -------------------------
# sold_date: 31 maj 2016
# address: Åsgatan 5
# location: Kungälv - Centrum,
#           Kungälvs kommun
# boarea: 120
#
#
# biarea: 60 m²
# rooms:
#                 6
# plot: 948 m² tomt
# price: 5 565 000 kr
# -------------------------
# sold_date: 31 maj 2016
# address: Hemmansgatan 3
# location: Ytterby-Tega,
#           Kungälvs kommun
# boarea: 158
# biarea: None
# rooms:
#                 6
# plot: 859 m² tomt
# price: 3 855 000 kr
# -------------------------
# sold_date: 31 maj 2016
# address: Jakobsvägen 27
# location: Aröd,
#           Kungälvs kommun
# boarea: 140
# biarea: None
# rooms:
#                 6
# plot: 2 050 m² tomt
# price: 4 850 000 kr
# -------------------------
# sold_date: 30 maj 2016
# address: Olserödsgatan 114
# location: Kungälv - Olseröd,
#           Kungälvs kommun
# boarea: 144
#
#
# biarea: 132 m²
# rooms:
#                 6
# plot: 712 m² tomt
# price: 5 325 000 kr
# -------------------------
# sold_date: 27 maj 2016
# address: Slånbärsvägen 15
# location: Munkegärde Östra,
#           Kungälvs kommun
# boarea: 145
#
#
# biarea: 31 m²
# rooms:
#                 6
# plot: 647 m² tomt
# price: 5 100 000 kr
# -------------------------
# sold_date: 26 maj 2016
# address: Rosenstensvägen 33
# location: Kode,
#           Kungälvs kommun
# boarea: 112
# biarea: None
# rooms:
#                 6
# plot: 620 m² tomt
# price: 3 400 000 kr
# -------------------------
# sold_date: 26 maj 2016
# address: Stinneröd 260
# location: Bohuslän,
#           Kungälvs kommun
# boarea: 65
#
#
# biarea: 65 m²
# rooms:
#                 6
# plot: 1 734 m² tomt
# price: 1 300 000 kr
# -------------------------
# sold_date: 26 maj 2016
# address: Onyxvägen 22
# location: Kode lantligt,
#           Kungälvs kommun
# boarea: 123
# biarea: None
# rooms:
#                 6
# plot: 566 m² tomt
# price: 3 210 000 kr
# -------------------------
# sold_date: 26 maj 2016
# address: Hällristningsgatan 26
# location: Ytterby Stället,
#           Kungälvs kommun
# boarea: 75
# biarea: None
# rooms:
#                 6
# plot: 404 m² tomt
# price: 2 995 000 kr
# -------------------------
# sold_date: 23 maj 2016
# address: Duvesjön 371
# location: Romelanda-Duvesjön,
#           Kungälvs kommun
# boarea: 4
# biarea: None
# rooms:
#                 6
# plot: 1 808 m² tomt
# price: 3 600 000 kr
# -------------------------
# sold_date: 23 maj 2016
# address: Mjölnarvägen 16
# location: Romelanda,
#           Kungälvs kommun
# boarea: 121
#
#
# biarea: 47 m²
# rooms:
#                 6
# plot: 831 m² tomt
# price: 2 385 000 kr
# -------------------------
# sold_date: 21 maj 2016
# address: Lerskärsvägen 63
# location: Tjuvkil,
#           Kungälvs kommun
# boarea: 110
#
#
# biarea: 10 m²
# rooms:
#                 6
# plot: 884 m² tomt
# price: 3 875 000 kr
# -------------------------
# sold_date: 21 maj 2016
# address: Briljantvägen 36
# location: Kode,
#           Kungälvs kommun
# boarea: 150
# biarea: None
# rooms:
#                 6
# plot: 462 m² tomt
# price: 4 100 000 kr
# -------------------------
# sold_date: 17 maj 2016
# address: Jägarvägen 6
# location: Romelanda,
#           Kungälvs kommun
# boarea: 159
#
#
# biarea: 16 m²
# rooms:
#                 6
# plot: 564 m² tomt
# price: 3 625 000 kr
# -------------------------
# sold_date: 16 maj 2016
# address: Plogvägen 174
# location: Ullstorp,
#           Kungälvs kommun
# boarea: 122
# biarea: None
# rooms:
#                 6
# plot: 308 m² tomt
# price: 4 175 000 kr
# -------------------------
# sold_date: 15 maj 2016
# address: Brunnefjällsvägen 3
# location: Vedhall,
#           Kungälvs kommun
# boarea: 94
#
#
# biarea: 16 m²
# rooms:
#                 6
# plot: 1 067 m² tomt
# price: 2 695 000 kr
# -------------------------
# sold_date: 14 maj 2016
# address: Toreby 380
# location: Harestad,
#           Kungälvs kommun
# boarea: 157
#
#
# biarea: 99 m²
# rooms:
#                 6
# plot: 2 591 m² tomt
# price: 2 902 500 kr
# -------------------------
# sold_date: 13 maj 2016
# address: Hemvägen 25
# location: Romelanda - Diseröd,
#           Kungälvs kommun
# boarea: 138
#
#
# biarea: 19 m²
# rooms:
#                 6
# plot: 381 m² tomt
# price: 3 250 000 kr
# -------------------------
# sold_date: 12 maj 2016
# address: Solskiftegatan 14
# location: Ytterby - Tega,
#           Kungälvs kommun
# boarea: 171
#
#
# biarea: 25 m²
# rooms:
#                 6
# plot: 1 091 m² tomt
# price: 3 900 000 kr
# -------------------------
# sold_date: 12 maj 2016
# address: Marias Väg 2
# location: Aröd,
#           Kungälvs kommun
# boarea: 90
# biarea: None
# rooms:
#                 6
# plot: 1 608 m² tomt
# price: 3 400 000 kr
# -------------------------
# sold_date: 11 maj 2016
# address: Almvägen 3
# location: Romelanda - Diseröd,
#           Kungälvs kommun
# boarea: 130
# biarea: None
# rooms:
#                 6
# plot: 727 m² tomt
# price: 3 300 000 kr
# -------------------------
# sold_date: 9 maj 2016
# address: Solvagnsgatan 3
# location: Ytterby - Stället,
#           Kungälvs kommun
# boarea: 140
# biarea: None
# rooms:
#                 6
# plot: 360 m² tomt
# price: 4 300 000 kr
# -------------------------
# sold_date: 9 maj 2016
# address: Skårby Mosse 880
# location: Skårby,
#           Kungälvs kommun
# boarea: 86,3
#
#
# biarea: 40 m²
# rooms:
#                 6
# plot: 1 782 m² tomt
# price: 2 900 000 kr
# -------------------------
# sold_date: 6 maj 2016
# address: Ugglehed 180
# location: Önneröd,
#           Kungälvs kommun
# boarea: 106
#
#
# biarea: 64 m²
# rooms:
#                 6
# plot: 15 352 m² tomt
# price: 2 730 000 kr
# -------------------------
# sold_date: 1 maj 2016
# address: Vena 318
# location: Ytterby,
#           Kungälvs kommun
# boarea: 112
# biarea: None
# rooms:
#                 6
# plot: 9 024 m² tomt
# price: 4 100 000 kr
# -------------------------
# sold_date: 1 maj 2016
# address: Duvesjön 225
# location: Romelanda,
#           Kungälvs kommun
# boarea: 65
# biarea: None
# rooms:
#                 6
# plot: 1 800 m² tomt
# price: 1 950 000 kr
# -------------------------
# sold_date: 29 april 2016
# address: Duvesjön 201
# location: Duvesjön,
#           Kungälvs kommun
# boarea: 38
#
#
# biarea: 9 m²
# rooms:
#                 6
# plot: 1 390 m² tomt
# price: 1 300 000 kr
# -------------------------
# sold_date: 28 april 2016
# address: Munkholmsgatan 2
# location: Centralt,
#           Kungälvs kommun
# boarea: 137
#
#
# biarea: 73 m²
# rooms:
#                 6
# plot: 893 m² tomt
# price: 4 900 000 kr
# -------------------------
# sold_date: 28 april 2016
# address: Björkstigen 9
# location: Romelanda,
#           Kungälvs kommun
# boarea: 185
#
#
# biarea: 46 m²
# rooms:
#                 6
# plot: 937 m² tomt
# price: 3 700 000 kr
# -------------------------
# sold_date: 25 april 2016
# address: Settungsvägen 62
# location: Ullstorp,
#           Kungälvs kommun
# boarea: 140
#
#
# biarea: 26 m²
# rooms:
#                 6
# plot: 372 m² tomt
# price: 4 450 000 kr
# -------------------------
# sold_date: 24 april 2016
# address: Situlagatan 2
# location: Ytterby,
#           Kungälvs kommun
# boarea: 150
#
#
# biarea: 20 m²
# rooms:
#                 6
# plot: 787 m² tomt
# price: 4 500 000 kr
# -------------------------
# sold_date: 22 april 2016
# address: Äslingsvägen 8
# location: Tjuvkil,
#           Kungälvs kommun
# boarea: 183
# biarea: None
# rooms:
#                 6
# plot: 1 380 m² tomt
# price: 5 650 000 kr
# -------------------------
# sold_date: 21 april 2016
# address: Kärrhed 190
# location: Kärna,
#           Kungälvs kommun
# boarea: 122
# biarea: None
# rooms:
#                 6
# plot: 1 316 m² tomt
# price: 2 850 000 kr
# -------------------------
# sold_date: 14 april 2016
# address: Olvonvägen 71
# location: Kungälv - Romelanda,
#           Kungälvs kommun
# boarea: 115
#
#
# biarea: 115 m²
# rooms:
#                 6
# plot: 2 056 m² tomt
# price: 4 725 000 kr
# -------------------------
# sold_date: 14 april 2016
# address: Rättarevägen 16
# location: Ytterby,
#           Kungälvs kommun
# boarea: 105
#
#
# biarea: 122 m²
# rooms:
#                 6
# plot: 732 m² tomt
# price: 4 300 000 kr
# -------------------------
# sold_date: 12 april 2016
# address: Ametistvägen 11
# location: Kode,
#           Kungälvs kommun
# boarea: 107
# biarea: None
# rooms:
#                 6
# plot: 806 m² tomt
# price: 2 850 000 kr
# -------------------------
# sold_date: 9 april 2016
# address: Rådalsvägen 25 Havsutsikt
# location: Aröd,
#           Kungälvs kommun
# boarea: 88
# biarea: None
# rooms:
#                 6
# plot: 1 462 m² tomt
# price: 2 995 000 kr
# -------------------------
# sold_date: 8 april 2016
# address: Annas Väg 10
# location: Kärna,
#           Kungälvs kommun
# boarea: 62
# biarea: None
# rooms:
#                 6
# plot: 1 317 m² tomt
# price: 2 600 000 kr
# -------------------------
